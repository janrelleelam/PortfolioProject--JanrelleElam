# %%
#Import libraries...smtplib allows you to send emails to yourself
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
#Connect to website
url= 'https://www.thesablecollective.com/products/bold-statement-ring'
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8"}
page= requests.get(url, headers=headers)
soup1= BeautifulSoup(page.content, "html.parser")
print(soup1)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta content="SZJoweDL0d08b8UMfxpxR5JZ8XB_t302uOgwlw2JZ5o" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, height=device-height, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="" name="theme-color"/>
# <title>
#       Bold statement ring – The Sable Collective
#     </title><meta content="Make a statement with our 'BOLD' statement ring! This chic, minimalist ring is the perfect way to add a touch of simplicity and style to any outfit. Embrace the power and confidence that comes with wearing a bold statement piece. Gold plated over stainless steel. Long lasting. " name="description"/><link href="https://www.thesablecollective.com/products/bold-statement-ring" rel="canonical"/><meta content="product" property="og:type"/>
# ...

# %%
#Prettify data (Cleans formatting a bit)
url= 'https://www.thesablecollective.com/products/bold-statement-ring'
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8"}
soup1= BeautifulSoup(page.content, "html.parser")
soup2= BeautifulSoup(soup1.prettify(), "html.parser")
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta content="SZJoweDL0d08b8UMfxpxR5JZ8XB_t302uOgwlw2JZ5o" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, height=device-height, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="" name="theme-color"/>
# <title>
#    Bold statement ring – The Sable Collective
#   </title>
# <meta content="Make a statement with our 'BOLD' statement ring! This chic, minimalist ring is the perfect way to add a touch of simplicity and style to any outfit. Embrace the power and confidence that comes with wearing a bold statement piece. Gold plated over stainless steel. Long lasting. " name="description"/>
# <link href="https://www.thesablecollective.com/products/bold-statement-ring" rel="canonical"/>
# <meta content="product" property="og:type"/>
# ...

# %%
#Pull Title
url= 'https://www.thesablecollective.com/products/bold-statement-ring'
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8"}
soup1= BeautifulSoup(page.content, "html.parser")
soup2= BeautifulSoup(soup1.prettify(), "html.parser")
Title= soup2.find(class_= "ProductMeta__Title Heading u-h2").text.strip()
print(Title)
# Out:
# Bold statement ring

# %%
#Pull Price
url= 'https://www.thesablecollective.com/products/bold-statement-ring'
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8"}
soup1= BeautifulSoup(page.content, "html.parser")
soup2= BeautifulSoup(soup1.prettify(), "html.parser")
Title= soup2.find(class_= "ProductMeta__Title Heading u-h2").text.strip()
Price= soup2.find(class_="ProductMeta__Price Price Text--subdued u-h4").text.strip()
print(Title)
print(Price)
type(Price)

#<span class="ProductMeta__Price Price Text--subdued u-h4">$32.00 USD</span>
# Out:
# Bold statement ring
# $32.00 USD
# str

# %%
#Create date stamp
import datetime
Today= datetime.date.today()
print(Today)
# Out:
# 2024-04-18

# %%
#Create CSV containing data (ONLY RUN ONE TIME OR YOU WILL DELETE ALL OF YOUR DATA IRL)- Comment out
#import csv

#header= ['Title', 'Price', 'Date']
#data= [Title, Price, Today]

#with open('The_Sable_Collective_Web_Scraper_Dataset.csv', 'w', newline='', encoding='UTF8') as f:
    #writer= csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\janre\The_Sable_Collective_Web_Scraper_Dataset.csv")
print(df)
# Out:
#                  Title       Price        Date
# 0  Bold statement ring  $32.00 USD  2024-04-18
# 1  Bold statement ring  $32.00 USD  2024-04-18
# 2  Bold statement ring  $32.00 USD  2024-04-18
# 3  Bold statement ring  $32.00 USD  2024-04-18

# %%
# Append Data to csv
with open('The_Sable_Collective_Web_Scraper_Dataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer= csv.writer(f)
    writer.writerow(data)

# %%
#Begin appending automation process

def check_price():
    url= 'https://www.thesablecollective.com/products/bold-statement-ring'
    headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0", "Accept-Encoding": "gzip, deflate, br", "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8"}
    page= requests.get(url, headers=headers)
    soup1= BeautifulSoup(page.content, "html.parser")
    soup2= BeautifulSoup(soup1.prettify(), "html.parser")
    Title= soup2.find(class_= "ProductMeta__Title Heading u-h2").text.strip()
    Price= soup2.find(class_="ProductMeta__Price Price Text--subdued u-h4").text.strip()
    import datetime
    Today= datetime.date.today()
    import csv
    header= ['Title', 'Price', 'Date']
    data= [Title, Price, Today]
    with open('The_Sable_Collective_Web_Scraper_Dataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer= csv.writer(f)
        writer.writerow(data)

#To receive an email in the event that data reaches a particular value add the following code, run it then run the code in the last cell
    if(Price<16):
        send_mail()

# %%
#Test: Add time for automation uses seconds, and we want to update every 5 seconds. Run code to enable automation...must press stop button at top to make code stop running
#while(True):
   # check_price()
   # time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[143], line 4
#       2 while(True):
#       3     check_price()
# ----> 4     time.sleep(5)
#
# KeyboardInterrupt:

# %%
# Test Run
#import pandas as pd
#df= pd.read_csv(r"C:\Users\janre\The_Sable_Collective_Web_Scraper_Dataset.csv")
#print(df)
# Out:
#                   Title       Price        Date
# 0   Bold statement ring  $32.00 USD  2024-04-18
# 1   Bold statement ring  $32.00 USD  2024-04-18
# 2   Bold statement ring  $32.00 USD  2024-04-18
# 3   Bold statement ring  $32.00 USD  2024-04-18
# 4   Bold statement ring  $32.00 USD  2024-04-18
# 5   Bold statement ring  $32.00 USD  2024-04-18
# 6   Bold statement ring  $32.00 USD  2024-04-18
# 7   Bold statement ring  $32.00 USD  2024-04-18
# 8   Bold statement ring  $32.00 USD  2024-04-18
# 9   Bold statement ring  $32.00 USD  2024-04-18
# 10  Bold statement ring  $32.00 USD  2024-04-18

# %%
#We want to update every 24hours (86400 seconds). Run code to enable automation...must press stop button at top to make code stop running
while(True):
    check_price()
    time.sleep(86400)

# %%
#Run to view updates
import pandas as pd
df= pd.read_csv(r"C:\Users\janre\The_Sable_Collective_Web_Scraper_Dataset.csv")
print(df)

# %%
#Email Alert
def send_mail():
    server = smtplib.SMTP_SSL('smtp.yahoo.com',465)
    server.ehlo()
    #server.starttls()
server.ehlo()
server.login('janrelleelam@yahoo.com', 'xxxxxxxxxx')

subject= "Time to buy the ring Janrelle"
body= "The price one that cute ring is now $15 or less...Press the Button! It is time buy."
msg= f"Subject: {subject}\n\n{body}"
server.sendmail(
    'janrelleelam@yahoo.com', msg)
